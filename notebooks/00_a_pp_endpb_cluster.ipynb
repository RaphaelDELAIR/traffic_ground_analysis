# %%
from traffic.core import Traffic

# %%
import pandas as pd
# Out:
# /home/service/miniconda3/envs/py39v7/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import altair as alt
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %%
from traffic.data import airports

# %%
from ground_analysis.utils import within_Xmin
from ground_analysis.extract_flight_info import onehot_runways, assign_twy_occ
# Out:
# /home/service/miniconda3/envs/py39v7/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from ground_analysis.utils import within_Xmin

# %% [markdown]
# # end pb k neighbours ?

# %%
df = pd.DataFrame({'a':[3,5], 'b':[4,9]})
df.append({'a':5, 'b':45}, ignore_index=True)
# Out:
#    a   b
# 0  3   4
# 1  5   9
# 2  5  45

# %%
#t_5_10_endpb=Traffic.from_flights([f.pushback('LSZH').stop for f in t_5_10])

endpblatlon_df = pd.DataFrame()
for f in t_5_10:
    pb = f.pushback('LSZH')
    pp = f.on_parking_position('LSZH').max()
    if pb is not None and pp is not None:
        gate = pp.parking_position_max
        vec = pb.data.sort_values('timestamp').iloc[-1]
        endpblatlon_df = endpblatlon_df.append({'lat':vec['latitude'], 'lon':vec['longitude'], 'gate':gate}, ignore_index=True)
endpblatlon_df
# Out:
# /home/service/miniconda3/envs/py39v7/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     gate        lat       lon
# 0    E26  47.459494  8.557399
# 1    E34  47.459564  8.556659
# 2    A48  47.451976  8.556043
# 3    A15  47.455084  8.557663
# 4    A03  47.455724  8.569952
# ..   ...        ...       ...
# 236  E42  47.459690  8.554728
# 237  F75  47.455227  8.567894
# 238  F75  47.455227  8.567894
# 239  A44  47.453407  8.559448
# 240  A09  47.454886  8.559600
#
# [241 rows x 3 columns]

# %%
endpb_chart = alt.Chart(endpblatlon_df).mark_point().encode(longitude='lon', latitude='lat', color='gate')

airports['LSZH'].geoencode() + endpb_chart
# Out:
# alt.LayerChart(...)

# %%
endpblatlon_df['apron'] = endpblatlon_df.gate.str.get(0)

# %%
endpblatlon_df.head()
# Out:
# /home/service/miniconda3/envs/py39v7/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   gate        lat       lon apron
# 0  E26  47.459494  8.557399     E
# 1  E34  47.459564  8.556659     E
# 2  A48  47.451976  8.556043     A
# 3  A15  47.455084  8.557663     A
# 4  A03  47.455724  8.569952     A

# %% [raw]
# endpblatlon_df.to_pickle('../data/samples/endpblatlon_df.pkl')

# %%
endpblatlon_df[['lat', 'lon', 'apron']].values
# Out:
# /home/service/miniconda3/envs/py39v7/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# array([[47.45949438062765, 8.557398869441105, 'E'],
#        [47.45956420898438, 8.556659405048077, 'E'],
#        [47.451976194220066, 8.556043184720552, 'A'],
#        [47.45508355609441, 8.557662963867188, 'A'],
#        [47.455723649364394, 8.569952157827522, 'A'],
#        [47.454687862072966, 8.56076167179988, 'A'],
#        [47.4521484375, 8.555963516235353, 'A'],
#        [47.460949138059455, 8.55037395770733, 'E'],
#        [47.46099569029727, 8.563789954552282, 'E'],
#        [47.4551650225106, 8.556078397310698, 'A'],
#        [47.449020127118644, 8.559617262620193, 'D'],
# ...

# %%
from sklearn.cluster import DBSCAN 
clustering_endpb = DBSCAN()
