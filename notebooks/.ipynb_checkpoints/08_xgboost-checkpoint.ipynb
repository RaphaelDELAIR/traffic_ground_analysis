# %%
# %load_ext lab_black

# %% [markdown]
# # import

# %%
# one hot encode runway
# ordinal encode airline
# TODO: Try with avg pb time, ratioH/M, ratio nominal
from traffic.core import Traffic

import pandas as pd
import numpy as np
import pickle

import os.path

from ipyleaflet import Polygon
from ipywidgets import Layout
from ipyleaflet import Map, Marker

from cartes.osm import Overpass

from sklearn import svm

from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix

from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, GridSearchCV

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import altair as alt

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor

import matplotlib.pyplot as plt

from collections import namedtuple

import os

# %%
from ground_analysis.build_features import gather_data

# %%
import xgboost

# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import altair as alt

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt

from collections import namedtuple

import os


ResMetrics = namedtuple(  # create a personalized tuple
    "ResMetrics", "mae mse rmse acc1min acc3min acc5min r2"
)


def within_Xmin(real, pred, m=1):
    assert len(real) == len(pred)
    c = 0
    for r, p in zip(real, pred):
        if abs(r - p) < m:
            c += 1
    return c / len(real) * 100


def plot_results(labels_test, predicted):
    # plot pred vs truth
    data_chart = pd.DataFrame(
        {"true": labels_test.values.reshape((-1,)), "pred": predicted}
    )
    predVStrue_chart = alt.Chart(data_chart).mark_circle(opacity=0.5).encode(
        x="true", y="pred"
    ) + alt.Chart(
        pd.DataFrame({"x": np.linspace(0, 25, 10), "y": np.linspace(0, 25, 10)})
    ).mark_line(
        color="black"
    ).encode(
        x="x", y="y"
    )
    return predVStrue_chart


def feature_importance_chart(feature_columns, clf):
    col = feature_columns
    # modelname.feature_importance_
    y = clf.feature_importances_
    datachart = pd.DataFrame({"feature": col, "importance": y}).sort_values(
        "importance"
    )
    chart = (
        alt.Chart(datachart)
        .mark_bar()
        .encode(alt.Y("feature", sort="-x"), alt.X("importance"))
        .transform_window(
            rank="rank(importance)",
            sort=[alt.SortField("importance", order="descending")],
        )
        .transform_filter((alt.datum.rank < 20))
        .configure_axis(
            labelFont="Ubuntu",
            titleFont="Fira Sans",
            labelFontSize=15,
            titleFontSize=16,
        )
        .configure_legend(
            orient="bottom", labelFontSize=14, titleFontSize=14, labelFont="Ubuntu"
        )
        .configure_view(stroke=None)
        .configure_title(font="Fira Sans", fontSize=18, anchor="start", dy=-10)
        .configure_header(
            labelFont="Ubuntu",
            labelFontSize=18,
            labelOrient="top",
        )
        .properties(width=200)
    )
    return chart


def plot_feature_importance(
    feature_columns,
    clf,  # saveas="../prediction_results/result.png"
):
    col = feature_columns
    # modelname.feature_importance_
    y = clf.feature_importances_
    # plot
    fig, ax = plt.subplots()
    width = 0.2  # the width of the bars
    ind = np.arange(len(y))  # the x locations for the groups
    ax.barh(ind, y, width, color="green")
    ax.set_yticks(ind + width / 10)
    ax.set_yticklabels(col, minor=False)
    plt.title("Feature importance in RandomForest Classifier")
    plt.xlabel("Relative importance")
    plt.ylabel("feature")
    plt.figure(figsize=(5, 8))
    fig.set_size_inches(6.5, 9.5, forward=True)
    return fig


def results(labels_test, predicted):
    mae = mean_absolute_error(labels_test.values.reshape((-1,)), predicted)
    mse = mean_squared_error(labels_test.values.reshape((-1,)), predicted)
    rmse = mse ** (1 / 2)
    acc1min = within_Xmin(labels_test.values.reshape((-1,)), predicted)
    acc3min = within_Xmin(labels_test.values.reshape((-1,)), predicted, m=3)
    acc5min = within_Xmin(labels_test.values.reshape((-1,)), predicted, m=5)
    r2 = r2_score(labels_test.values.reshape((-1,)), predicted)

    return ResMetrics(
        mae=mae,
        mse=mse,
        rmse=rmse,
        acc1min=acc1min,
        acc3min=acc3min,
        acc5min=acc5min,
        r2=r2,
    )


def train_rf(
    flight_df,
    feature_columns,
    target_column,
    query,
    dirname="../prediction_results/rf/",
    dropna=True,
):
    """
    function that will train and plot performance metric
    """
    test_name = dirname.split("/")[-2]
    flight_df = flight_df.query(query)
    data_df = flight_df[feature_columns + [target_column, "on_runway_time"]]
    if dropna:
        data_df = data_df.dropna()
    else:
        data_df = (
            data_df.sort_values("on_runway_time").fillna(method="backfill").dropna()
        )
    data_df = data_df.drop(["on_runway_time"], axis=1)
    input_df = data_df[feature_columns]
    target_df = data_df[[target_column]]

    data_train, data_test, labels_train, labels_test = train_test_split(
        input_df, target_df, test_size=0.20, random_state=42
    )

    #  dtrain = xgb.DMatrix(data_train, label=labels_train)
    #  dtest = xgb.DMatrix(data_test, label=labels_test)
    #
    #
    #  # specify parameters via map, definition are same as c++ version
    #  param = {'max_depth':2, 'eta':1, 'silent':1, 'objective':'binary:logistic'}

    #  # specify validations set to watch performance
    #  watchlist = [(dtest, 'eval'), (dtrain, 'train')]
    #  num_round = 2
    #  bst = xgb.train(param, dtrain, num_round, watchlist)

    #  # this is prediction
    #  preds = bst.predict(dtest)
    #  labels = dtest.get_label()
    #  print('error=%f' % (sum(1 for i in range(len(preds)) if int(preds[i] > 0.5) != labels[i]) / float(len(preds))))
    #  bst.save_model('0001.model')
    #  # dump model
    #  bst.dump_model('dump.raw.txt')
    #  # dump model with feature map
    #  bst.dump_model('dump.nice.txt', '../data/featmap.txt')

    clf = GradientBoostingRegressor(
        n_estimators=150, min_samples_split=10, random_state=42
    )
    # RandomForestRegressor(n_estimators=150, min_samples_split=10, random_state=42)

    # fit the model on the whole dataset
    clf.fit(data_train, labels_train)
    # make a single prediction
    predicted = clf.predict(data_test)

    res_metrics = results(labels_test, predicted)

    res_txt = "Results for Random Forest on the following features :\n"
    res_txt += " ".join(feature_columns) + "\n"
    res_txt += f"Target var : {target_column}\n"
    res_txt += "Selecting the subset with following query : \n" + query + "\n"
    res_txt += f"mae=\t{res_metrics.mae}\nmse=\t{res_metrics.mse}\nrmse=\t{res_metrics.rmse}\nacc1min={res_metrics.acc1min}\nacc3min={res_metrics.acc3min}\nacc5min={res_metrics.acc5min}\nR2=\t{res_metrics.r2}\n"
    res_txt += f"n_sample training : {data_train.shape[0]}\nn_sample test : {data_test.shape[0]}\nn_sample_tot={input_df.shape[0]}\n"

    print(res_txt)

    corr_chart = plot_results(labels_test, predicted)
    feature_chart = plot_feature_importance(feature_columns, clf)
    top10features_chart = feature_importance_chart(feature_columns, clf)

    os.makedirs(os.path.dirname(dirname), exist_ok=True)
    with open(dirname + "res.txt", "w") as text_file:
        text_file.write(res_txt)
    with open(dirname + f"{test_name}.pkl", "wb") as pklfile:
        pickle.dump(res_metrics, pklfile)

    feature_chart.savefig(dirname + "features.png")
    corr_chart.save(dirname + "corr_chart.html")
    top10features_chart.save(dirname + "top10features.html")
    display(top10features_chart)

    with open(dirname + "clf.pkl", "wb") as f:
        pickle.dump(clf, f)

    return res_metrics, labels_test, predicted, clf

# %% [markdown]
# # Load

# %%
dep_arr_df = pd.read_pickle(
    "../data/processed/dep_arr_df14_nextavgdelaybetteraffected.pkl"
)

# %%
dep_arr_df["DEP"] = np.where(dep_arr_df["mvt_type"] == "DEP", 1, 0)

# %% [markdown]
# # Feature sets

# %%
dict_feature_sets = {}
dict_feature_sets["target_cols"] = [
    "taxi_holding_time_minutes",
    "total_holding_time_minutes",
    "real_dur_minutes",
    "avg_delay_30min",
    "avg_delay_30min_all_trajs",
    "avg_delay_in30min",
    "avg_delay_in60min",
    "avg_delay_in90min",
    "avg_delay_in30min_cat",
    "avg_delay_in60min_cat",
    "avg_delay_in90min_cat",
    "taxi_holding_time_minutes_cat",
]
dict_feature_sets["taxi_geom_cols"] = ["taxi_dist", "angle_sum"]
dict_feature_sets["leaving_gate_cols"] = ["turnaround_minutes", "sifi_DEP", "sifi_ARR"]
dict_feature_sets["additional_cols"] = [
    "max_turnaround_minutes_last30T",
    "hh_num",
    "avg_delay_30min",
]
dict_feature_sets["one_hot_flight_rel"] = [
    "H",
    "L",
    "L/M",
    "M",
    "runway_10",
    "runway_14",
    "runway_16",
    "runway_28",
    "runway_32",
    "runway_34",
]
dict_feature_sets["wtc_counts_ratios"] = [
    "H_count",
    "L_count",
    "L/M_count",
    "M_count",
    "H_count_ratio",
    "L_count_ratio",
    "L/M_count_ratio",
    "M_count_ratio",
]
dict_feature_sets["twy_occ_cols"] = [
    "H_occ",
    "K_occ",
    "B_occ",
    "F_occ",
    "L_occ",
    "J_occ",
    "E_occ",
    "D_occ",
    "C_occ",
    "N_occ",
    "A_occ",
    "M_occ",
    "Y_occ",
    "R_occ",
    "G_occ",
    "Z_occ",
    "P_occ",
    "twy_pca_0",
    "twy_pca_1",
    "twy_pca_2",
]
dict_feature_sets["aqlis_scfis_cols"] = [
    "aqli_DEP",
    "scfi_DEP",
    "aqli_ARR",
    "scfi_ARR",
    "mean_sifi_DEP_last30T",
    "mean_sifi_ARR_last30T",
    "mean_aqli_DEP_last30T",
    "mean_scfi_DEP_last30T",
    "mean_aqli_ARR_last30T",
    "mean_scfi_ARR_last30T",
]
dict_feature_sets["weather_cols"] = [
    "press",
    "temp",
    "atmap_visibility",
    "atmap_wind",
    "atmap_precipitation",
    "atmap_freezing",
    "atmap_danger",
    "atmap_score",
]
dict_feature_sets["apt_congest_cols"] = [
    "nominal",
    "busy",
    "disrupted",
    "not_nom_arrival_ratio",
    "nb_arr",
    "nb_dep",
    "nb",
    "avg_speed_last30T",
    "avg_speed_last15T",
    "config_EAST",
    "config_NORTH0",
    "config_NORTH1",
    "config_SOUTH",
]

dict_feature_sets["taxi_profile_cols"] = ["avg_speed"]

# %%
main_feature_sets = dict(
    wang_all=dict_feature_sets["taxi_geom_cols"]
    + dict_feature_sets["leaving_gate_cols"]
    + dict_feature_sets["additional_cols"]
    + dict_feature_sets["one_hot_flight_rel"]
    + dict_feature_sets["wtc_counts_ratios"]
    + dict_feature_sets["twy_occ_cols"]
    + dict_feature_sets["aqlis_scfis_cols"]
    + dict_feature_sets["weather_cols"]
    + dict_feature_sets["apt_congest_cols"]
    + ["DEP"],
    wang_noaqlis=dict_feature_sets["taxi_geom_cols"]
    + dict_feature_sets["leaving_gate_cols"]
    + dict_feature_sets["additional_cols"]
    + dict_feature_sets["one_hot_flight_rel"]
    + dict_feature_sets["wtc_counts_ratios"]
    + dict_feature_sets["twy_occ_cols"]
    + dict_feature_sets["weather_cols"]
    + dict_feature_sets["apt_congest_cols"]
    + ["DEP"],
    wang_few=["taxi_dist", "angle_sum", "DEP", "temp", "sifi_DEP"],
    # For prediction of average delay : no flight specific feature
    avg_delay_pred=  # dict_feature_sets["taxi_geom_cols"]
    # + dict_feature_sets["leaving_gate_cols"]
    dict_feature_sets["additional_cols"]  # max turnaround 30 min is ok
    # + dict_feature_sets["one_hot_flight_rel"]
    + dict_feature_sets["wtc_counts_ratios"]
    + dict_feature_sets["twy_occ_cols"]
    + dict_feature_sets["weather_cols"]
    + dict_feature_sets["apt_congest_cols"],
    # + ["DEP"], we know it is a departure
)

# %% [markdown]
# # Taxi time prediction

# %%
import xgboost as xgb

# %% [markdown]
# ## GradientBoostingRegressor (sklearn)

# %%
base_dir = "../prediction_results/"
df_res = pd.DataFrame()
target_col = "real_dur_minutes"
# avg_delay_in30min   real_dur_minutes taxi_holding_time_minutes

for i, (set_name, features) in enumerate(main_feature_sets.items()):
    test_name = f"10{i}_{target_col}_{set_name}/"
    res, labels_test, predicted, clf = train_rf(
        dep_arr_df,
        features,
        target_col,
        query="parking_position==parking_position",
        dirname=base_dir + test_name,
        dropna=False,
    )
    d_res = res._asdict()
    d_res["name"] = test_name
    df_res = df_res.append(d_res, ignore_index=True)

tolatex = df_res.transpose()
tolatex.columns = tolatex.loc["name"]
print(tolatex.to_latex())

df_res_taxitime = df_res
# Out:
# Results for Random Forest on the following features :
# taxi_dist angle_sum turnaround_minutes sifi_DEP sifi_ARR max_turnaround_minutes_last30T hh_num avg_delay_30min H L L/M M runway_10 runway_14 runway_16 runway_28 runway_32 runway_34 H_count L_count L/M_count M_count H_count_ratio L_count_ratio L/M_count_ratio M_count_ratio H_occ K_occ B_occ F_occ L_occ J_occ E_occ D_occ C_occ N_occ A_occ M_occ Y_occ R_occ G_occ Z_occ P_occ twy_pca_0 twy_pca_1 twy_pca_2 aqli_DEP scfi_DEP aqli_ARR scfi_ARR mean_sifi_DEP_last30T mean_sifi_ARR_last30T mean_aqli_DEP_last30T mean_scfi_DEP_last30T mean_aqli_ARR_last30T mean_scfi_ARR_last30T press temp atmap_visibility atmap_wind atmap_precipitation atmap_freezing atmap_danger atmap_score nominal busy disrupted not_nom_arrival_ratio nb_arr nb_dep nb avg_speed_last30T avg_speed_last15T config_EAST config_NORTH0 config_NORTH1 config_SOUTH DEP
# Target var : real_dur_minutes
# Selecting the subset with following query :
# parking_position==parking_position
# mae=	1.5274583243520359
# mse=	11.336107842995917
# rmse=	3.3669136969925315
# acc1min=47.67233661593554
# acc3min=89.57027752909579
# acc5min=97.76186213070726
# R2=	0.6350085425644294
# n_sample training : 8936
# n_sample test : 2234
# n_sample_tot=11170
# alt.Chart(...)
# Results for Random Forest on the following features :
# taxi_dist angle_sum turnaround_minutes sifi_DEP sifi_ARR max_turnaround_minutes_last30T hh_num avg_delay_30min H L L/M M runway_10 runway_14 runway_16 runway_28 runway_32 runway_34 H_count L_count L/M_count M_count H_count_ratio L_count_ratio L/M_count_ratio M_count_ratio H_occ K_occ B_occ F_occ L_occ J_occ E_occ D_occ C_occ N_occ A_occ M_occ Y_occ R_occ G_occ Z_occ P_occ twy_pca_0 twy_pca_1 twy_pca_2 press temp atmap_visibility atmap_wind atmap_precipitation atmap_freezing atmap_danger atmap_score nominal busy disrupted not_nom_arrival_ratio nb_arr nb_dep nb avg_speed_last30T avg_speed_last15T config_EAST config_NORTH0 config_NORTH1 config_SOUTH DEP
# Target var : real_dur_minutes
# Selecting the subset with following query :
# parking_position==parking_position
# mae=	1.8967483480955694
# mse=	16.178921343669842
# rmse=	4.02230299003815
# acc1min=43.2408236347359
# acc3min=83.3930170098478
# acc5min=94.40465532676812
# R2=	0.4790832830149847
# n_sample training : 8936
# n_sample test : 2234
# n_sample_tot=11170
# alt.Chart(...)
# Results for Random Forest on the following features :
# taxi_dist angle_sum DEP temp sifi_DEP
# Target var : real_dur_minutes
# Selecting the subset with following query :
# parking_position==parking_position
# mae=	2.070999289441809
# mse=	19.001392235234217
# rmse=	4.359058640949238
# acc1min=41.529568697198755
# acc3min=79.76878612716763
# acc5min=93.50822587816808
# R2=	0.4376958665038867
# n_sample training : 8996
# n_sample test : 2249
# n_sample_tot=11245
# alt.Chart(...)
# Results for Random Forest on the following features :
# max_turnaround_minutes_last30T hh_num avg_delay_30min H_count L_count L/M_count M_count H_count_ratio L_count_ratio L/M_count_ratio M_count_ratio H_occ K_occ B_occ F_occ L_occ J_occ E_occ D_occ C_occ N_occ A_occ M_occ Y_occ R_occ G_occ Z_occ P_occ twy_pca_0 twy_pca_1 twy_pca_2 press temp atmap_visibility atmap_wind atmap_precipitation atmap_freezing atmap_danger atmap_score nominal busy disrupted not_nom_arrival_ratio nb_arr nb_dep nb avg_speed_last30T avg_speed_last15T config_EAST config_NORTH0 config_NORTH1 config_SOUTH
# Target var : real_dur_minutes
# Selecting the subset with following query :
# parking_position==parking_position
# mae=	3.3171763615561263
# mse=	27.78387919271345
# rmse=	5.2710415662099885
# acc1min=19.427036705461056
# acc3min=55.19247985675918
# acc5min=82.63205013428828
# R2=	0.10543559569011052
# n_sample training : 8936
# n_sample test : 2234
# n_sample_tot=11170
# alt.Chart(...)
# Results for Random Forest on the following features :
# max_turnaround_minutes_last30T hh_num M_count L_count_ratio L/M_count_ratio H_occ D_occ C_occ M_occ Y_occ R_occ Z_occ press temp atmap_precipitation atmap_freezing atmap_score nominal not_nom_arrival_ratio config_NORTH0
# Target var : real_dur_minutes
# Selecting the subset with following query :
# parking_position==parking_position
# mae=	3.5045208803531245
# mse=	29.317409051062967
# rmse=	5.414555295780344
# acc1min=17.367949865711726
# acc3min=50.53715308863026
# acc5min=80.88630259623993
# R2=	0.05606015697939082
# n_sample training : 8936
# n_sample test : 2234
# n_sample_tot=11170
# alt.Chart(...)
# Results for Random Forest on the following features :
# max_turnaround_minutes_last30T hh_num H_count L_count L/M_count M_count L_count_ratio H_occ J_occ M_occ Z_occ press temp atmap_score nominal busy disrupted not_nom_arrival_ratio config_EAST config_NORTH0
# Target var : real_dur_minutes
# Selecting the subset with following query :
# parking_position==parking_position
# mae=	3.4425791908745524
# mse=	28.735792186591475
# rmse=	5.360577598224978
# acc1min=18.03939122649955
# acc3min=52.01432408236347
# acc5min=81.11011638316921
# R2=	0.07478661847505474
# n_sample training : 8936
# n_sample test : 2234
# n_sample_tot=11170
# alt.Chart(...)
# Results for Random Forest on the following features :
# max_turnaround_minutes_last30T hh_num avg_delay_30min H_count L_count L/M_count M_count H_count_ratio L_count_ratio L/M_count_ratio M_count_ratio H_occ K_occ B_occ F_occ L_occ J_occ E_occ D_occ C_occ N_occ A_occ M_occ Y_occ R_occ G_occ Z_occ twy_pca_0 twy_pca_1 twy_pca_2 press temp atmap_visibility atmap_wind atmap_precipitation atmap_freezing atmap_danger atmap_score nominal busy disrupted not_nom_arrival_ratio nb_arr nb_dep nb avg_speed_last30T avg_speed_last15T config_EAST config_NORTH0 config_SOUTH
# Target var : real_dur_minutes
# Selecting the subset with following query :
# parking_position==parking_position
# mae=	3.3204228969014036
# mse=	27.821707277752274
# rmse=	5.274628638847694
# acc1min=18.889883616830797
# acc3min=55.19247985675918
# acc5min=82.58728737690242
# R2=	0.10421763551528318
# n_sample training : 8936
# n_sample test : 2234
# n_sample_tot=11170
# alt.Chart(...)
# Results for Random Forest on the following features :
# max_turnaround_minutes_last30T hh_num avg_delay_30min H_count L_count L/M_count M_count H_count_ratio L_count_ratio L/M_count_ratio M_count_ratio H_occ K_occ B_occ F_occ L_occ J_occ E_occ D_occ C_occ N_occ A_occ M_occ Y_occ R_occ G_occ Z_occ twy_pca_0 twy_pca_1 twy_pca_2 press temp atmap_visibility atmap_wind atmap_precipitation atmap_freezing atmap_danger atmap_score nominal busy disrupted not_nom_arrival_ratio nb_arr nb_dep nb avg_speed_last30T avg_speed_last15T config_EAST config_NORTH0 config_SOUTH
# Target var : real_dur_minutes
# Selecting the subset with following query :
# parking_position==parking_position
# mae=	3.3204228969014036
# mse=	27.821707277752274
# rmse=	5.274628638847694
# acc1min=18.889883616830797
# acc3min=55.19247985675918
# acc5min=82.58728737690242
# R2=	0.10421763551528318
# n_sample training : 8936
# n_sample test : 2234
# n_sample_tot=11170
# alt.Chart(...)
# Results for Random Forest on the following features :
# max_turnaround_minutes_last30T hh_num H_count L_count L/M_count M_count L_count_ratio L/M_count_ratio H_occ K_occ B_occ F_occ L_occ J_occ D_occ C_occ N_occ M_occ Y_occ R_occ Z_occ P_occ press temp atmap_visibility atmap_wind atmap_precipitation atmap_freezing atmap_danger atmap_score nominal busy disrupted not_nom_arrival_ratio config_EAST config_NORTH0 config_NORTH1 config_SOUTH
# Target var : real_dur_minutes
# Selecting the subset with following query :
# parking_position==parking_position
# mae=	3.455469804085811
# mse=	28.96734334552983
# rmse=	5.382131858801848
# acc1min=18.621307072515666
# acc3min=52.05908683974933
# acc5min=81.15487914055505
# R2=	0.06733130875655868
# n_sample training : 8936
# n_sample test : 2234
# n_sample_tot=11170
# alt.Chart(...)
# \begin{tabular}{llllllllll}
# \toprule
# name &  100\_real\_dur\_minutes\_wang\_all/ &  101\_real\_dur\_minutes\_wang\_noaqlis/ &  102\_real\_dur\_minutes\_wang\_few/ &  103\_real\_dur\_minutes\_avg\_delay\_pred/ &  104\_real\_dur\_minutes\_sfs\_backward\_20/ &  105\_real\_dur\_minutes\_sfs\_forward\_20/ & 106\_real\_dur\_minutes\_from\_avg\_delay\_pred\_to\_rfecv/ &  107\_real\_dur\_minutes\_from\_wang\_to\_rfecv/ &  108\_real\_dur\_minutes\_sfs\_backward\_38/ \\
# \midrule
# acc1min &                       47.672337 &                           43.240824 &                       41.529569 &                             19.427037 &                               17.36795 &                             18.039391 &                                          18.889884 &                                 18.889884 &                              18.621307 \\
# acc3min &                       89.570278 &                           83.393017 &                       79.768786 &                              55.19248 &                              50.537153 &                             52.014324 &                                           55.19248 &                                  55.19248 &                              52.059087 \\
# acc5min &                       97.761862 &                           94.404655 &                       93.508226 &                              82.63205 &                              80.886303 &                             81.110116 &                                          82.587287 &                                 82.587287 &                              81.154879 \\
# mae     &                        1.527458 &                            1.896748 &                        2.070999 &                              3.317176 &                               3.504521 &                              3.442579 &                                           3.320423 &                                  3.320423 &                                3.45547 \\
# mse     &                       11.336108 &                           16.178921 &                       19.001392 &                             27.783879 &                              29.317409 &                             28.735792 &                                          27.821707 &                                 27.821707 &                              28.967343 \\
# name    &  100\_real\_dur\_minutes\_wang\_all/ &  101\_real\_dur\_minutes\_wang\_noaqlis/ &  102\_real\_dur\_minutes\_wang\_few/ &  103\_real\_dur\_minutes\_avg\_delay\_pred/ &  104\_real\_dur\_minutes\_sfs\_backward\_20/ &  105\_real\_dur\_minutes\_sfs\_forward\_20/ &  106\_real\_dur\_minutes\_from\_avg\_delay\_pred\_to\_rf... &  107\_real\_dur\_minutes\_from\_wang\_to\_rfecv/ &  108\_real\_dur\_minutes\_sfs\_backward\_38/ \\
# r2      &                        0.635009 &                            0.479083 &                        0.437696 &                              0.105436 &                                0.05606 &                              0.074787 &                                           0.104218 &                                  0.104218 &                               0.067331 \\
# rmse    &                        3.366914 &                            4.022303 &                        4.359059 &                              5.271042 &                               5.414555 &                              5.360578 &                                           5.274629 &                                  5.274629 &                               5.382132 \\
# \bottomrule
# \end{tabular}

# %%
config_NORTH0 config_NORTH1 config_SOUTH DEP
Target var : real_dur_minutes
Selecting the subset with following query : 
parking_position==parking_position
mae=	1.4718066535249896
mse=	11.877074405468342
rmse=	3.4463131612591944
acc1min=51.74574753804835
acc3min=89.83885407341093
acc5min=97.3142345568487
R2=	0.6175909088584555
n_sample training : 8936
n_sample test : 2234
n_sample_tot=11170


Target var : real_dur_minutes
Selecting the subset with following query : 
parking_position==parking_position
mae=	1.8604498612441709
mse=	16.893578281516906
rmse=	4.110179835666185
acc1min=46.01611459265891
acc3min=83.21396598030438
acc5min=94.40465532676812
R2=	0.45607329749580083
n_sample training : 8936
n_sample test : 2234
n_sample_tot=11170



Target var : real_dur_minutes
Selecting the subset with following query : 
parking_position==parking_position
mae=	2.1162275600198313
mse=	20.09416935865158
rmse=	4.482652045235229
acc1min=41.84081814139618
acc3min=79.54646509559804
acc5min=92.04090706980881
R2=	0.40535754698074344
n_sample training : 8996
n_sample test : 2249
n_sample_tot=11245

# %% [markdown]
# ## GradientBoostingRegressor (xgboost)

# %%
def train_xgboost(
    flight_df,
    feature_columns,
    target_column,
    query,
    num_round=35,
    dirname="../prediction_results/rf/",
    dropna=True,
):
    """
    function that will train and plot performance metric
    """
    test_name = dirname.split("/")[-2]
    flight_df = flight_df.query(query)
    data_df = flight_df[feature_columns + [target_column, "on_runway_time"]]
    if dropna:
        data_df = data_df.dropna()
    else:
        data_df = (
            data_df.sort_values("on_runway_time").fillna(method="backfill").dropna()
        )
    data_df = data_df.drop(["on_runway_time"], axis=1)
    input_df = data_df[feature_columns]
    target_df = data_df[[target_column]]

    data_train, data_test, labels_train, labels_test = train_test_split(
        input_df, target_df, test_size=0.20, random_state=42
    )

    dtrain = xgb.DMatrix(data_train, label=labels_train)
    dtest = xgb.DMatrix(data_test, label=labels_test)

    # specify parameters via map, definition are same as c++ version
    param = {
        "max_depth": 4,
        "objective": "reg:squarederror",
        "reg_alpha": 0.01,
        "eta": 0.01,
        "eval_metric": "mse",
    }

    # specify validations set to watch performance
    watchlist = [(dtest, "eval"), (dtrain, "train")]
    bst = xgb.train(
        param,
        dtrain,
        # watchlist,
        evals=[(dtest, "Test")],
        early_stopping_rounds=10,
        #num_boost_round=500,
    )

    # this is prediction
    preds = bst.predict(dtest)
    labels = dtest.get_label()

    print(preds.shape, labels.shape)

    res_metrics = results_xgb(labels, preds)
    res_txt = "Results for XGBOOST on the following features :\n"
    res_txt += " ".join(feature_columns) + "\n"
    res_txt += f"Target var : {target_column}\n"
    res_txt += "Selecting the subset with following query : \n" + query + "\n"
    res_txt += f"mae=\t{res_metrics.mae}\nmse=\t{res_metrics.mse}\nrmse=\t{res_metrics.rmse}\nacc1min={res_metrics.acc1min}\nacc3min={res_metrics.acc3min}\nacc5min={res_metrics.acc5min}\nR2=\t{res_metrics.r2}\n"
    res_txt += f"n_sample training : {data_train.shape[0]}\nn_sample test : {data_test.shape[0]}\nn_sample_tot={input_df.shape[0]}\n"

    print(res_txt)

    # corr_chart = plot_results(labels_test, predicted)

    os.makedirs(os.path.dirname(dirname), exist_ok=True)
    with open(dirname + "res.txt", "w") as text_file:
        text_file.write(res_txt)
    with open(dirname + f"{test_name}.pkl", "wb") as pklfile:
        pickle.dump(res_metrics, pklfile)

    # bst.save_model(dirname + "0001.model")
    # dump model
    # bst.dump_model(dirname + "dump.raw.txt")
    # dump model with feature map
    # bst.dump_model(dirname + "dump.nice.txt", dirname + "featmap.txt")
    return res_metrics, labels_test, predicted, clf

# %%
def results_xgb(labels_test, predicted):
    mae = mean_absolute_error(labels_test.reshape((-1,)), predicted)
    mse = mean_squared_error(labels_test.reshape((-1,)), predicted)
    rmse = mse ** (1 / 2)
    acc1min = within_Xmin(labels_test.reshape((-1,)), predicted)
    acc3min = within_Xmin(labels_test.reshape((-1,)), predicted, m=3)
    acc5min = within_Xmin(labels_test.reshape((-1,)), predicted, m=5)
    r2 = r2_score(labels_test.reshape((-1,)), predicted)

    return ResMetrics(
        mae=mae,
        mse=mse,
        rmse=rmse,
        acc1min=acc1min,
        acc3min=acc3min,
        acc5min=acc5min,
        r2=r2,
    )

# %%
base_dir = "../prediction_results/"
df_res = pd.DataFrame()
target_col = "avg_delay_in30min"
# avg_delay_in30min   real_dur_minutes taxi_holding_time_minutes

for i, (set_name, features) in enumerate(main_feature_sets.items()):
    test_name = f"21{i}_{target_col}_{set_name}/"
    res, labels_test, predicted, clf = train_xgboost(
        dep_arr_df,
        features,
        target_col,
        query="parking_position==parking_position",
        dirname=base_dir + test_name,
        dropna=False,
    )
    d_res = res._asdict()
    d_res["name"] = test_name
    df_res = df_res.append(d_res, ignore_index=True)

tolatex = df_res.transpose()
tolatex.columns = tolatex.loc["name"]
print(tolatex.to_latex())

df_res_taxitime = df_res
# Out:
# [0]	eval-rmse:2.25975	train-rmse:1.89775
# [1]	eval-rmse:2.20561	train-rmse:1.79546
# [2]	eval-rmse:2.18083	train-rmse:1.70560
# [3]	eval-rmse:2.14473	train-rmse:1.62892
# [4]	eval-rmse:2.13226	train-rmse:1.60022
# [5]	eval-rmse:2.08964	train-rmse:1.51971
# [6]	eval-rmse:2.11117	train-rmse:1.43409
# [7]	eval-rmse:2.10198	train-rmse:1.39365
# [8]	eval-rmse:2.08593	train-rmse:1.36029
# [9]	eval-rmse:2.07622	train-rmse:1.33970
# [10]	eval-rmse:2.05448	train-rmse:1.31047
# [11]	eval-rmse:2.05009	train-rmse:1.26040
# [12]	eval-rmse:2.04790	train-rmse:1.22501
# [13]	eval-rmse:2.00402	train-rmse:1.17769
# [14]	eval-rmse:1.99811	train-rmse:1.13757
# [15]	eval-rmse:1.99571	train-rmse:1.10797
# [16]	eval-rmse:1.99036	train-rmse:1.07777
# [17]	eval-rmse:2.00041	train-rmse:1.04430
# [18]	eval-rmse:1.99918	train-rmse:1.01751
# [19]	eval-rmse:2.00236	train-rmse:0.99952
# [20]	eval-rmse:2.00732	train-rmse:0.98107
# [21]	eval-rmse:2.01443	train-rmse:0.96446
# [22]	eval-rmse:2.01788	train-rmse:0.95169
# [23]	eval-rmse:2.01888	train-rmse:0.92543
# [24]	eval-rmse:2.01984	train-rmse:0.89948
# (2234,) (2234,)
# Results for XGBOOST on the following features :
# taxi_dist angle_sum turnaround_minutes sifi_DEP sifi_ARR max_turnaround_minutes_last30T hh_num avg_delay_30min H L L/M M runway_10 runway_14 runway_16 runway_28 runway_32 runway_34 H_count L_count L/M_count M_count H_count_ratio L_count_ratio L/M_count_ratio M_count_ratio H_occ K_occ B_occ F_occ L_occ J_occ E_occ D_occ C_occ N_occ A_occ M_occ Y_occ R_occ G_occ Z_occ P_occ twy_pca_0 twy_pca_1 twy_pca_2 aqli_DEP scfi_DEP aqli_ARR scfi_ARR mean_sifi_DEP_last30T mean_sifi_ARR_last30T mean_aqli_DEP_last30T mean_scfi_DEP_last30T mean_aqli_ARR_last30T mean_scfi_ARR_last30T press temp atmap_visibility atmap_wind atmap_precipitation atmap_freezing atmap_danger atmap_score nominal busy disrupted not_nom_arrival_ratio nb_arr nb_dep nb avg_speed_last30T avg_speed_last15T config_EAST config_NORTH0 config_NORTH1 config_SOUTH DEP
# Target var : avg_delay_in30min
# Selecting the subset with following query :
# parking_position==parking_position
# mae=	1.3586583137512207
# mse=	4.079750061035156
# rmse=	2.0198391176118844
# acc1min=49.91047448522829
# acc3min=91.00268576544315
# acc5min=97.8961504028648
# R2=	0.312901214088381
# n_sample training : 8936
# n_sample test : 2234
# n_sample_tot=11170
#
# [0]	eval-rmse:2.26426	train-rmse:1.89510
# [1]	eval-rmse:2.20507	train-rmse:1.79784
# [2]	eval-rmse:2.21080	train-rmse:1.71712
# [3]	eval-rmse:2.19487	train-rmse:1.63861
# [4]	eval-rmse:2.17200	train-rmse:1.57481
# [5]	eval-rmse:2.14049	train-rmse:1.50557
# [6]	eval-rmse:2.13151	train-rmse:1.45446
# [7]	eval-rmse:2.11739	train-rmse:1.41532
# [8]	eval-rmse:2.10564	train-rmse:1.37581
# [9]	eval-rmse:2.09852	train-rmse:1.32858
# [10]	eval-rmse:2.10039	train-rmse:1.30512
# [11]	eval-rmse:2.08380	train-rmse:1.27084
# [12]	eval-rmse:2.08098	train-rmse:1.24171
# [13]	eval-rmse:2.08025	train-rmse:1.22076
# [14]	eval-rmse:2.07691	train-rmse:1.20962
# [15]	eval-rmse:2.06970	train-rmse:1.18645
# [16]	eval-rmse:2.06728	train-rmse:1.15685
# [17]	eval-rmse:2.05080	train-rmse:1.12906
# [18]	eval-rmse:2.05901	train-rmse:1.10438
# [19]	eval-rmse:2.05904	train-rmse:1.08748
# [20]	eval-rmse:2.05552	train-rmse:1.06636
# [21]	eval-rmse:2.06982	train-rmse:1.03258
# [22]	eval-rmse:2.07112	train-rmse:1.00965
# [23]	eval-rmse:2.07353	train-rmse:0.98678
# [24]	eval-rmse:2.07441	train-rmse:0.97516
# (2234,) (2234,)
# Results for XGBOOST on the following features :
# taxi_dist angle_sum turnaround_minutes sifi_DEP sifi_ARR max_turnaround_minutes_last30T hh_num avg_delay_30min H L L/M M runway_10 runway_14 runway_16 runway_28 runway_32 runway_34 H_count L_count L/M_count M_count H_count_ratio L_count_ratio L/M_count_ratio M_count_ratio H_occ K_occ B_occ F_occ L_occ J_occ E_occ D_occ C_occ N_occ A_occ M_occ Y_occ R_occ G_occ Z_occ P_occ twy_pca_0 twy_pca_1 twy_pca_2 press temp atmap_visibility atmap_wind atmap_precipitation atmap_freezing atmap_danger atmap_score nominal busy disrupted not_nom_arrival_ratio nb_arr nb_dep nb avg_speed_last30T avg_speed_last15T config_EAST config_NORTH0 config_NORTH1 config_SOUTH DEP
# Target var : avg_delay_in30min
# Selecting the subset with following query :
# parking_position==parking_position
# mae=	1.3526690006256104
# mse=	4.303158760070801
# rmse=	2.0744056401945112
# acc1min=50.85049239033125
# acc3min=91.04744852282901
# acc5min=97.98567591763653
# R2=	0.2752754822625263
# n_sample training : 8936
# n_sample test : 2234
# n_sample_tot=11170
#
# [0]	eval-rmse:2.20077	train-rmse:2.09421
# [1]	eval-rmse:2.22003	train-rmse:2.06393
# [2]	eval-rmse:2.23391	train-rmse:2.01392
# [3]	eval-rmse:2.25920	train-rmse:1.98975
# [4]	eval-rmse:2.26399	train-rmse:1.94195
# [5]	eval-rmse:2.29230	train-rmse:1.91490
# [6]	eval-rmse:2.29659	train-rmse:1.87780
# [7]	eval-rmse:2.30231	train-rmse:1.86107
# [8]	eval-rmse:2.30050	train-rmse:1.84587
# [9]	eval-rmse:2.33532	train-rmse:1.81244
# [10]	eval-rmse:2.34581	train-rmse:1.80043
# [11]	eval-rmse:2.35181	train-rmse:1.78862
# [12]	eval-rmse:2.35489	train-rmse:1.77902
# [13]	eval-rmse:2.36728	train-rmse:1.75837
# [14]	eval-rmse:2.37185	train-rmse:1.74935
# [15]	eval-rmse:2.37783	train-rmse:1.72999
# [16]	eval-rmse:2.38549	train-rmse:1.71244
# [17]	eval-rmse:2.39322	train-rmse:1.69572
# [18]	eval-rmse:2.39301	train-rmse:1.68040
# [19]	eval-rmse:2.40332	train-rmse:1.66487
# [20]	eval-rmse:2.40372	train-rmse:1.65417
# [21]	eval-rmse:2.40777	train-rmse:1.64101
# [22]	eval-rmse:2.41516	train-rmse:1.62964
# [23]	eval-rmse:2.42542	train-rmse:1.61403
# [24]	eval-rmse:2.42765	train-rmse:1.60344
# (2249,) (2249,)
# Results for XGBOOST on the following features :
# taxi_dist angle_sum DEP temp sifi_DEP
# Target var : avg_delay_in30min
# Selecting the subset with following query :
# parking_position==parking_position
# mae=	1.7538526058197021
# mse=	5.893475532531738
# rmse=	2.427648148420965
# acc1min=38.72832369942196
# acc3min=83.85949310804803
# acc5min=96.3983992885727
# R2=	-0.0032879737553594968
# n_sample training : 8996
# n_sample test : 2249
# n_sample_tot=11245
#
# [0]	eval-rmse:1.98967	train-rmse:1.85762
# [1]	eval-rmse:1.94983	train-rmse:1.76976
# [2]	eval-rmse:1.92274	train-rmse:1.69327
# [3]	eval-rmse:1.90523	train-rmse:1.63236
# [4]	eval-rmse:1.89873	train-rmse:1.60480
# [5]	eval-rmse:1.89220	train-rmse:1.55736
# [6]	eval-rmse:1.88368	train-rmse:1.53181
# [7]	eval-rmse:1.88016	train-rmse:1.50701
# [8]	eval-rmse:1.86244	train-rmse:1.48166
# [9]	eval-rmse:1.85724	train-rmse:1.45549
# [10]	eval-rmse:1.86013	train-rmse:1.43364
# [11]	eval-rmse:1.85692	train-rmse:1.40545
# [12]	eval-rmse:1.85752	train-rmse:1.37949
# [13]	eval-rmse:1.85098	train-rmse:1.35330
# [14]	eval-rmse:1.85056	train-rmse:1.33579
# [15]	eval-rmse:1.84437	train-rmse:1.30784
# [16]	eval-rmse:1.83548	train-rmse:1.26463
# [17]	eval-rmse:1.84053	train-rmse:1.23464
# [18]	eval-rmse:1.84068	train-rmse:1.22097
# [19]	eval-rmse:1.83406	train-rmse:1.18575
# [20]	eval-rmse:1.83913	train-rmse:1.15691
# [21]	eval-rmse:1.82725	train-rmse:1.13547
# [22]	eval-rmse:1.82094	train-rmse:1.10400
# [23]	eval-rmse:1.82639	train-rmse:1.08623
# [24]	eval-rmse:1.81702	train-rmse:1.05644
# (2234,) (2234,)
# Results for XGBOOST on the following features :
# max_turnaround_minutes_last30T hh_num avg_delay_30min H_count L_count L/M_count M_count H_count_ratio L_count_ratio L/M_count_ratio M_count_ratio H_occ K_occ B_occ F_occ L_occ J_occ E_occ D_occ C_occ N_occ A_occ M_occ Y_occ R_occ G_occ Z_occ P_occ twy_pca_0 twy_pca_1 twy_pca_2 press temp atmap_visibility atmap_wind atmap_precipitation atmap_freezing atmap_danger atmap_score nominal busy disrupted not_nom_arrival_ratio nb_arr nb_dep nb avg_speed_last30T avg_speed_last15T config_EAST config_NORTH0 config_NORTH1 config_SOUTH
# Target var : avg_delay_in30min
# Selecting the subset with following query :
# parking_position==parking_position
# mae=	1.3091944456100464
# mse=	3.3015594482421875
# rmse=	1.817019385764001
# acc1min=51.43240823634736
# acc3min=91.36078782453
# acc5min=97.76186213070726
# R2=	0.4439616769366579
# n_sample training : 8936
# n_sample test : 2234
# n_sample_tot=11170
#
# \begin{tabular}{lllll}
# \toprule
# name &  210\_avg\_delay\_in30min\_wang\_all/ &  211\_avg\_delay\_in30min\_wang\_noaqlis/ &  212\_avg\_delay\_in30min\_wang\_few/ &  213\_avg\_delay\_in30min\_avg\_delay\_pred/ \\
# \midrule
# acc1min &                        49.910474 &                            50.850492 &                        38.728324 &                              51.432408 \\
# acc3min &                        91.002686 &                            91.047449 &                        83.859493 &                              91.360788 \\
# acc5min &                         97.89615 &                            97.985676 &                        96.398399 &                              97.761862 \\
# mae     &                         1.358658 &                             1.352669 &                         1.753853 &                               1.309194 \\
# mse     &                          4.07975 &                             4.303159 &                         5.893476 &                               3.301559 \\
# name    &  210\_avg\_delay\_in30min\_wang\_all/ &  211\_avg\_delay\_in30min\_wang\_noaqlis/ &  212\_avg\_delay\_in30min\_wang\_few/ &  213\_avg\_delay\_in30min\_avg\_delay\_pred/ \\
# r2      &                         0.312901 &                             0.275275 &                        -0.003288 &                               0.443962 \\
# rmse    &                         2.019839 &                             2.074406 &                         2.427648 &                               1.817019 \\
# \bottomrule
# \end{tabular}

# %%
df_res
# Out:
#      acc1min    acc3min    acc5min       mae       mse  \
# 0  49.910474  91.002686  97.896150  1.358658  4.079750
# 1  50.850492  91.047449  97.985676  1.352669  4.303159
# 2  38.728324  83.859493  96.398399  1.753853  5.893476
# 3  51.432408  91.360788  97.761862  1.309194  3.301559
#
#                                     name        r2      rmse
# 0        210_avg_delay_in30min_wang_all/  0.312901  2.019839
# 1    211_avg_delay_in30min_wang_noaqlis/  0.275275  2.074406
# 2        212_avg_delay_in30min_wang_few/ -0.003288  2.427648
# 3  213_avg_delay_in30min_avg_delay_pred/  0.443962  1.817019

# %% [markdown]
# ### on sfs rfecv features

# %%
with open("../data/processed/main_feature_sets.pkl", "rb") as f:
    main_feature_sets = pickle.load(f)

# %%
selected_features_set_names = [
    "sfs_backward_20",
    "sfs_forward_20",
    "from_avg_delay_pred_to_rfecv",
    "from_wang_to_rfecv",
    "sfs_backward_38",
]

# %%
base_dir = "../prediction_results/"
df_res = pd.DataFrame()
target_col = "avg_delay_in30min"
# avg_delay_in30min   real_dur_minutes taxi_holding_time_minutes

for (i, set_name) in enumerate(selected_features_set_names):
    features = main_feature_sets[set_name]
    test_name = f"21{i}_{target_col}_{set_name}/"
    res, labels_test, predicted, clf = train_xgboost(
        dep_arr_df,
        features,
        target_col,
        query="parking_position==parking_position",
        dirname=base_dir + test_name,
        dropna=False,
        num_round=50,
    )
    d_res = res._asdict()
    d_res["name"] = test_name
    df_res = df_res.append(d_res, ignore_index=True)

tolatex = df_res.transpose()
tolatex.columns = tolatex.loc["name"]
print(tolatex.to_latex())

df_res_taxitime = df_res
# Out:
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# /tmp/ipykernel_200276/2109291006.py in <module>
#       7     features = main_feature_sets[set_name]
#       8     test_name = f"21{i}_{target_col}_{set_name}/"
# ----> 9     res, labels_test, predicted, clf = train_xgboost(
#      10         dep_arr_df,
#      11         features,
#
# /tmp/ipykernel_200276/4243154479.py in train_xgboost(flight_df, feature_columns, target_column, query, num_round, dirname, dropna)
#      42     # specify validations set to watch performance
#      43     watchlist = [(dtest, "eval"), (dtrain, "train")]
# ---> 44     bst = xgb.train(
#      45         param,
#      46         dtrain,
#
# ~/miniconda3/envs/traffic/lib/python3.9/site-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks)
#     187     Booster : a trained booster model
#     188     """
# --> 189     bst = _train_internal(params, dtrain,
#     190                           num_boost_round=num_boost_round,
#     191                           evals=evals,
#
# ~/miniconda3/envs/traffic/lib/python3.9/site-packages/xgboost/training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks, evals_result, maximize, verbose_eval, early_stopping_rounds)
#      74             show_stdv=False, cvfolds=None)
#      75
# ---> 76     bst = callbacks.before_training(bst)
#      77
#      78     for i in range(start_iteration, num_boost_round):
#
# ~/miniconda3/envs/traffic/lib/python3.9/site-packages/xgboost/callback.py in before_training(self, model)
#     374         '''Function called before training.'''
#     375         for c in self.callbacks:
# --> 376             model = c.before_training(model=model)
#     377             msg = 'before_training should return the model'
#     378             if self.is_cv:
#
# ~/miniconda3/envs/traffic/lib/python3.9/site-packages/xgboost/callback.py in before_training(self, model)
#     513
#     514     def before_training(self, model):
# --> 515         self.starting_round = model.num_boosted_rounds()
#     516         return model
#     517
#
# ~/miniconda3/envs/traffic/lib/python3.9/site-packages/xgboost/core.py in num_boosted_rounds(self)
#    2000         rounds = ctypes.c_int()
#    2001         assert self.handle is not None
# -> 2002         _check_call(_LIB.XGBoosterBoostedRounds(self.handle, ctypes.byref(rounds)))
#    2003         return rounds.value
#    2004
#
# ~/miniconda3/envs/traffic/lib/python3.9/site-packages/xgboost/core.py in _check_call(ret)
#     208     """
#     209     if ret != 0:
# --> 210         raise XGBoostError(py_str(_LIB.XGBGetLastError()))
#     211
#     212
#
# XGBoostError: [15:22:07] ../src/metric/metric.cc:49: Unknown metric function mse
# Stack trace:
#   [bt] (0) /home/service/miniconda3/envs/traffic/lib/libxgboost.so(+0xdfadf) [0x7fdd703acadf]
#   [bt] (1) /home/service/miniconda3/envs/traffic/lib/libxgboost.so(xgboost::Metric::Create(std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > const&, xgboost::GenericParameter const*)+0xa8) [0x7fdd704d5948]
#   [bt] (2) /home/service/miniconda3/envs/traffic/lib/libxgboost.so(+0x1d7134) [0x7fdd704a4134]
#   [bt] (3) /home/service/miniconda3/envs/traffic/lib/libxgboost.so(XGBoosterBoostedRounds+0x29) [0x7fdd7036ef69]
#   [bt] (4) /home/service/miniconda3/envs/traffic/lib/python3.9/lib-dynload/../../libffi.so.7(+0x69ed) [0x7fde0e1fc9ed]
#   [bt] (5) /home/service/miniconda3/envs/traffic/lib/python3.9/lib-dynload/../../libffi.so.7(+0x6077) [0x7fde0e1fc077]
#   [bt] (6) /home/service/miniconda3/envs/traffic/lib/python3.9/lib-dynload/_ctypes.cpython-39-x86_64-linux-gnu.so(+0x13dd7) [0x7fde0e215dd7]
#   [bt] (7) /home/service/miniconda3/envs/traffic/lib/python3.9/lib-dynload/_ctypes.cpython-39-x86_64-linux-gnu.so(+0x14464) [0x7fde0e216464]
#   [bt] (8) /home/service/miniconda3/envs/traffic/bin/python(_PyObject_MakeTpCall+0x316) [0x562da8e51986]

# %% [raw]
# df_res_avg_del_L1reg = df_res

# %% [raw]
# df_res_taxitime_ori = df_res_taxitime

# %%
df_res_avg_del_L1reg
# Out:
#      acc1min    acc3min    acc5min       mae       mse  \
# 0  54.789615  93.196061  98.388541  1.223608  3.217938
# 1  51.253357  92.524620  98.254252  1.296361  3.229993
# 2  50.895255  92.166517  98.343778  1.291680  3.254800
# 3  50.895255  92.166517  98.343778  1.291680  3.254800
# 4  53.222919  92.658908  98.388541  1.248389  3.022676
#
#                                                 name        r2      rmse
# 0             210_avg_delay_in30min_sfs_backward_20/  0.458045  1.793861
# 1              211_avg_delay_in30min_sfs_forward_20/  0.456015  1.797218
# 2  212_avg_delay_in30min_from_avg_delay_pred_to_r...  0.451837  1.804107
# 3          213_avg_delay_in30min_from_wang_to_rfecv/  0.451837  1.804107
# 4             214_avg_delay_in30min_sfs_backward_38/  0.490930  1.738585

# %%
49]	eval-rmse:1.73859	train-rmse:1.31600
